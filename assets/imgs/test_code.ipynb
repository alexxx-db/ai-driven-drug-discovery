# %%
# https://<databricks-instance>/ajax-api/2.0/fs/files/<Volumes/path/to/image>

# %md
# ![Description](https://<databricks-instance>/ajax-api/2.0/fs/files//Volumes/mmt_demos2/ai_driven_drug_discovery/imgs/AI-Drug-Discovery-Page2o.png)

# %%
import shutil
import os

# Source workspace file path
src_path = '/Workspace/Users/may.merkletan@databricks.com/REPOs/ai-driven-drug-discovery/notebooks/imgs/AI-Drug-Discovery-Page2.png'

# Destination UC volume path
dst_dir = '/Volumes/<catalog>/<schema>/<volume>/imgs'
dst_path = f'{dst_dir}/AI-Drug-Discovery-Page2.png'

# Create destination directory if it does not exist
os.makedirs(dst_dir, exist_ok=True)

# Copy file
shutil.copy(src_path, dst_path)
